# %% [markdown]
# ---
# title: Index
# tags: ['dev', 'test', 'misc']
# description: [ENTER SHORT DESCRIPTION]
# author: Hawk Eye
# created: [UNKNOWN]
# last_modified: 2025-03-24 04:55:38
# ---

# %%
# Omniversal Business Docs

## Account Register

### Business Information
- **Company Name:** Omniversal Media, LLC
- **EIN:** 99-3380052
- **D-U-N-S Number:** 13-219-6371
- **Registered Address:** 450 Crafton Circle, Apt 204, Charlottesville, VA 22911
- **Business Mailing Address:** 266 Orchard Way, North Augusta, SC 29860
- **New Business Phone Number:** [Insert New Number Here]

## Financial Accounts

### Mercury Bank Accounts
- **Business Checking Account 1:** 202515134703
- **Business Checking Account 2:** 202553514919
- **Business Checking Account 3:** 202485383743
- **Business Savings Account:** 202434055135
- **Bank Address:** 4501 23rd Avenue S, Fargo, ND 58104

## Login Information (For Secure Storage)

_(Manually enter usernames/passwords into your personal notebook for security.)_

- **T-Mobile Business Account** - [Login Link](https://business.t-mobile.com/)
- **Mercury Bank Business Portal** - [Login Link](https://mercury.com/)
- **Virginia Tax iFile** - [Login Link](https://www.tax.virginia.gov/)
- **Stripe Business Dashboard** - [Login Link](https://dashboard.stripe.com/)
- **Apple Business Account** - [Login Link](https://business.apple.com/)

## Compliance & Filing

### Virginia Business Tax Filing Schedule
| Tax Type | Filing Frequency | Due Date |
|----------|----------------|----------|
| **Sales & Use Tax** | Monthly/Quarterly | 20th of the following month |
| **Estimated Business Taxes** | Quarterly | April 15, June 15, Sept 15, Jan 15 |
| **LLC Annual Registration** | Annually | May 25 |
| **State Income Tax** | Annually | May 1 |

### Steps for Filing Sales Tax (Virginia)
1. **Log into [Virginia Tax iFile](https://www.tax.virginia.gov/).**
2. **File a "Zero Return" or enter sales figures.**
3. **Submit and pay any amount due before the 20th of the following month.**

## Business Credit Growth Plan

### Active Credit Accounts
- **T-Mobile Business Credit** - $5,000 approved
- **Apple Business Credit (To Be Secured)**

### Next Steps
1. **Secure Apple Business Credit Tomorrow**
2. **Apply for Vendor Net-30 Accounts (Uline, Quill, Grainger)**
3. **Monitor Business Credit Score via Nav.com**

## Website & Tech Infrastructure

### Domains & Hosting
- **OmniversalMedia.cc** - Primary Business Site (Pending Setup)
- **OmniversalMedia.net** - Redirect or Business Info Landing Page

### Next Steps
1. **Launch Quick Business Info Page on OmniversalMedia.cc**
2. **Secure VPS Hosting (After Business Credit Setup)**
3. **Deploy Nextcloud for Secure File Sharing**

---
This document serves as an organized reference for managing business information, finances, compliance, and credit growth. **Keep a physical copy for security and update regularly!**
