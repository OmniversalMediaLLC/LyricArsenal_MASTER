# %% [markdown]
# ---
# title: Master Notebook
# tags: ['infrastructure', 'core', 'index']
# description: [ENTER SHORT DESCRIPTION]
# author: Hawk Eye
# created: [UNKNOWN]
# last_modified: 2025-03-24 04:55:38
# ---

# %%
# Aether Master Playbook - Jupyter Notebook
# The One Notebook to Rule Them All
# Centralized Hub for Omniversal Media, Hawk Eye, & Aether Infrastructure

# Importing necessary libraries
import os
import pandas as pd

# Project Overview
project_overview = """
### Welcome to the Aether Master Playbook 🚀

This Jupyter Notebook serves as the centralized hub for **Omniversal Media, Hawk Eye's digital empire, and the full infrastructure of the Aether Plan.**

#### **What this Playbook Contains:**
- **Domains & GitHub Infrastructure** 🛰️
- **Docker Deployments (Nextcloud, Laravel, Ghost, WordPress, etc.)** 🏗️
- **Automation Scripts (SSL, Symlinks, Backups, Network Setup, etc.)** 🤖
- **SEO & Content Strategy** 📈
- **Monetization & Business Strategy** 💰
- **DigitalOcean & VPS Management** ☁️

This notebook is designed to be modular, meaning each section can be expanded and executed independently. Let’s build! 🔥
"""
print(project_overview)

# Domain Portfolio - Organized into Key Groupings
domains = [
    ("Core Infrastructure", ["Omniversal.Cloud", "Omniversal.Team", "OmniversalMedia.cc", "OmniversalMedia.org"]),
    ("Media & Content Delivery", ["Omniversal.Media", "OmniversalMedia.App", "OmniversalMedia.blog", "HawkEyeTheRapper.blog"]),
    ("Storytelling & Investigations", ["LyranWars.com", "TheGoverningConspiracy.com", "Omniversal.News"]),
    ("Client & Community", ["OmniversalMediaSolutions.com", "OmniversalMedia.co", "OmniversalMedia.online", "ReverseThisCurse.com"]),
    ("E-Commerce & Merch", ["OmniversalMedia.Shop", "Reincarnated.Store", "HawkEyeTheRapper.store"]),
    ("Hawk Eye’s Ecosystem", ["HawkEyeTheRapper.net", "HawkEyeTheRapper.app", "HawkEyeTheRapper.Live"])
]

df = pd.DataFrame([{ "Category": category, "Domain": domain } for category, domain_list in domains for domain in domain_list])

df.to_csv("domain_structure.csv", index=False)  # Save as a reference file
print("Domain Portfolio CSV Generated ✅")

display(df)  # Display domain structure

# Docker Deployment Structure
print("\nSetting up Docker Deployment Strategy...")
docker_services = [
    "MariaDB", "Nextcloud", "WordPress", "Drupal", "Laravel", "JupyterHub", "Ghost", "NGINX", "Let's Encrypt"
]

df_docker = pd.DataFrame(docker_services, columns=["Docker Services"])

df_docker.to_csv("docker_services.csv", index=False)
print("Docker Services CSV Generated ✅")

display(df_docker)

# Placeholder for automation scripts (symlinks, SSL, network setup)
def setup_symlinks():
    print("Creating necessary directories and symlinks... ✅")
    os.system("mkdir -p ~/docker-configs && mkdir -p /mnt/aether/docker-data && mkdir -p /mnt/aether/docker-backend")
    os.system("ln -s /mnt/aether/docker-data ~/docker-configs/docker-data")
    os.system("ln -s /mnt/aether/docker-backend ~/docker-configs/docker-backend")
    os.system("ln -s /mnt/aetherteam/nextcloud/backend ~/docker-configs/nextcloud-backend")
    print("Symlink setup completed ✅")

# Execute setup
setup_symlinks()

print("\nAether Master Playbook Initialized 🚀 Ready to expand and deploy!")
# Project Overview
# Out:
# ### Welcome to the Aether Master Playbook 🚀
#
# This Jupyter Notebook serves as the centralized hub for **Omniversal Media, Hawk Eye's digital empire, and the full infrastructure of the Aether Plan.**
#
# #### **What this Playbook Contains:**
# - **Domains & GitHub Infrastructure** 🛰️
# - **Docker Deployments (Nextcloud, Laravel, Ghost, WordPress, etc.)** 🏗️
# - **Automation Scripts (SSL, Symlinks, Backups, Network Setup, etc.)** 🤖
# - **SEO & Content Strategy** 📈
# - **Monetization & Business Strategy** 💰
# - **DigitalOcean & VPS Management** ☁️
#
# This notebook is designed to be modular, meaning each section can be expanded and executed independently. Let’s build! 🔥
#
# Domain Portfolio CSV Generated ✅
#                          Category                        Domain
# 0             Core Infrastructure              Omniversal.Cloud
# 1             Core Infrastructure               Omniversal.Team
# 2             Core Infrastructure            OmniversalMedia.cc
# ...
